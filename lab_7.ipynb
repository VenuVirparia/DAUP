# %%
import pandas as pd
import numpy as np
import sklearn.datasets as data

d1 = data.load_iris()
d1 

iris=pd.DataFrame(data=d1.data, columns=d1.feature_names)
iris

iris['target']=d1.target

X = d1.data
y = d1.target

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.36) #returns 4 arrays

# %%
from sklearn.naive_bayes import GaussianNB
nv = GaussianNB()

# %%
nv.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_predict=nv.predict(X_test)

# %%
df = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_predict.flatten()})
df.head()
# Out:
#    Actual  Predicted
# 0       1          1
# 1       0          0
# 2       1          1
# 3       1          1
# 4       1          1

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
print(accuracy_score(y_test,y_predict))
print(confusion_matrix(y_test,y_predict))
print(classification_report(y_test,y_predict))
# Out:
# 0.9629629629629629
# [[16  0  0]
#  [ 0 19  0]
#  [ 0  2 17]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       0.90      1.00      0.95        19
#            2       1.00      0.89      0.94        19
#
#     accuracy                           0.96        54
#    macro avg       0.97      0.96      0.96        54
# weighted avg       0.97      0.96      0.96        54

# %%
import matplotlib.pyplot as plt

# no need to write
df2 = df
df2.plot(kind='bar', figsize=(12,5))
plt.grid(which='major', linestyle='-', linewidth='0.5',color='green')
plt.show()

# %% [markdown]
# ## Titanic dataset

# %%
data2=pd.read_csv("train.csv")
data2.drop(["PassengerId","Name", "SibSp", "Parch", "Ticket","Fare","Cabin","Embarked"], axis="columns", inplace=True)
data2.head()

X = data2.drop(["Survived"], axis="columns")
y = data2["Survived"]

X.Sex = X.Sex.map({"male":0, "female":1})
#X.head()

X.Age = X.Age.fillna(X.Age.mean())
#X.Age[0:40]

X_train, X_test, y_train, y_test= train_test_split(X,y,train_size=0.75)

# %%
X_train.head()
# Out:
#      Pclass  Sex        Age
# 434       1    0  50.000000
# 549       2    0   8.000000
# 300       3    1  29.699118
# 299       1    1  50.000000
# 816       3    1  23.000000

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()

nb.fit(X_train, y_train)

y_predict=nb.predict(X_test)

df = pd.DataFrame({'Actual': y_test, 'Predicted': y_predict})
df.head()

from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
print(accuracy_score(y_test,y_predict))
print(confusion_matrix(y_test,y_predict))
print(classification_report(y_test,y_predict))
# Out:
# 0.8071748878923767
# [[116  20]
#  [ 23  64]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84       136
#            1       0.76      0.74      0.75        87
#
#     accuracy                           0.81       223
#    macro avg       0.80      0.79      0.80       223
# weighted avg       0.81      0.81      0.81       223

# %% [markdown]
# ## K-Nearest Neighbours

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=7)

# %%
import pandas as pd
import numpy as np
import sklearn.datasets as data

d1 = data.load_iris()
d1 

iris=pd.DataFrame(data=d1.data, columns=d1.feature_names)
iris

iris['target']=d1.target

X = d1.data
y = d1.target

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.36) #returns 4 arrays

# %%
knn.fit(X_train, y_train)

y_predict=knn.predict(X_test)

df = pd.DataFrame({'Actual': y_test, 'Predicted': y_predict})
print(df.head())

from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
print(accuracy_score(y_test,y_predict))
print(confusion_matrix(y_test,y_predict))
print(classification_report(y_test,y_predict))
# Out:
#    Actual  Predicted
# 0       2          2
# 1       2          2
# 2       1          1
# 3       2          2
# 4       2          1
# 0.9629629629629629
# [[10  0  0]
#  [ 0 21  1]
#  [ 0  1 21]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.95      0.95      0.95        22
#            2       0.95      0.95      0.95        22
#
#     accuracy                           0.96        54
#    macro avg       0.97      0.97      0.97        54
# weighted avg       0.96      0.96      0.96        54

# %%
data2=pd.read_csv("train.csv")
data2.drop(["PassengerId","Name", "SibSp", "Parch", "Ticket","Fare","Cabin","Embarked"], axis="columns", inplace=True)
data2.head()

X = data2.drop(["Survived"], axis="columns")
y = data2["Survived"]

X.Sex = X.Sex.map({"male":0, "female":1})
#X.head()

X.Age = X.Age.fillna(X.Age.mean())
#X.Age[0:40]

X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.32)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)

knn.fit(X_train, y_train)

y_predict=knn.predict(X_test)

df = pd.DataFrame({'Actual': y_test, 'Predicted': y_predict})
#print(df.head())

from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
print(accuracy_score(y_test,y_predict))
print(confusion_matrix(y_test,y_predict))
print(classification_report(y_test,y_predict))

confusionMatrix=confusion_matrix(y_test,y_predict)
# Out:
# 0.7377622377622378
# [[142  45]
#  [ 30  69]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.76      0.79       187
#            1       0.61      0.70      0.65        99
#
#     accuracy                           0.74       286
#    macro avg       0.72      0.73      0.72       286
# weighted avg       0.75      0.74      0.74       286

# %%
#!pip install seaborn 
#not in syllabus

import seaborn as sns
sns.heatmap(confusionMatrix,annot=True)
# Out:
# <Axes: >

# %%
import numpy as np
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

kf = KFold(n_splits=10, shuffle=False)
cv = cross_val_score(knn, X, y, cv=kf)
np.mean(cv)
# Out:
# 0.7699625468164795

# %%
cv
# Out:
# array([0.73333333, 0.82022472, 0.76404494, 0.79775281, 0.73033708,
#        0.79775281, 0.7752809 , 0.75280899, 0.82022472, 0.70786517])

# %%
kf
# Out:
# KFold(n_splits=10, random_state=None, shuffle=False)

# %%
#not to write
data2.head()
print(X_train.head())
# Out:
#      Pclass  Sex   Age
# 554       3    1  22.0
# 322       2    1  30.0
# 614       3    0  35.0
# 798       3    0  30.0
# 209       1    0  40.0

# %%
import pandas as pd


# initialize data of lists.
data = {'Survived': [0,1,0,1,1],
        'Pclass': [3, 2, 1, 3,2],
       'Sex':[0,1,1,1,0],
       'Age':[25,26,58,23,21]}

# Create DataFrame
unseen_new_test = pd.DataFrame(data)
print(f"\nunseen_new_test: \n{unseen_new_test}\n\n\n")

new_test=[[3,0,25],[2,1,26],[1,1,58],[3,1,23],[2,0,21]]
X_new_test = pd.DataFrame(new_test)

print(f"\nX_new_test = \n{X_new_test}\n\n")

#print(type(X_new_test))

y_predict=knn.predict(X_new_test)

print(f"\ny_predict = \n{y_predict}\n")

#df = pd.DataFrame({'Actual': y_test, 'Predicted': y_predict})
#print(df.head())
# Out:
# unseen_new_test:
#    Survived  Pclass  Sex  Age
# 0         0       3    0   25
# 1         1       2    1   26
# 2         0       1    1   58
# 3         1       3    1   23
# 4         1       2    0   21
#
#
#
#
# X_new_test =
#    0  1   2
# 0  3  0  25
# 1  2  1  26
# 2  1  1  58
# 3  3  1  23
# 4  2  0  21
#
#
#
# y_predict =
# [0 1 1 0 0]
# C:\Users\Student\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
